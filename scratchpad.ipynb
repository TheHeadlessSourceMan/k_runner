# %%
import k_runner

dir(k_runner)
# Out:
# ['AppRestartType',
#  'Application',
#  'ApplicationCallbacks',
#  'CmdLineWrapper',
#  'CommandLineOption',
#  'E',
#  'ErrIO',
#  'ErrorWindow',
#  'Frame',
#  'HelpSystemEntry',
#  'Iterable',
#  'Path',
#  'PossiblyRunningApplication',
#  'Process',
#  'ProcessCompatible',
#  'ProcessManipulator',
#  'PyErrRun',
#  'RunApp',
#  'RunSomething',
#  'Runner',
#  'Scrollbar',
#  'Text',
#  'Tk',
#  'UiComponent',
#  'UiGroupWithTabs',
#  'UiItem',
#  'UiItemGroup',
#  'Window',
#  'WindowManipulator',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'allSystemProcesses',
#  'argvToString',
#  'callbackDefs',
#  'cmdline',
#  'cmdlinewrapper',
#  'findProcess',
#  'findProcesses',
#  'findSystemProcesses',
#  'getHwndsByPid',
#  'getPidByHwnd',
#  'getProcessName',
#  'getTopLevelWindows',
#  'hasWindowsTools',
#  'helpfiles',
#  'kRunnerTools',
#  'kill',
#  'os',
#  'pidToHwnd',
# ...
